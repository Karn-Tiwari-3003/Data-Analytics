# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mpg.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 5    15.0          8         429.0        198    4341          10.0
# 6    14.0          8         454.0        220    4354           9.0
# 7    14.0          8         440.0        215    4312           8.5
# 8    14.0          8         455.0        225    4425          10.0
# 9    15.0          8         390.0        190    3850           8.5
# 10   15.0          8         383.0        170    3563          10.0
# 11   14.0          8         340.0        160    3609           8.0
# 12   15.0          8         400.0        150    3761           9.5
# ...

# %%
print(df)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 5    15.0          8         429.0        198    4341          10.0
# 6    14.0          8         454.0        220    4354           9.0
# 7    14.0          8         440.0        215    4312           8.5
# 8    14.0          8         455.0        225    4425          10.0
# 9    15.0          8         390.0        190    3850           8.5
# 10   15.0          8         383.0        170    3563          10.0
# 11   14.0          8         340.0        160    3609           8.0
# 12   15.0          8         400.0        150    3761           9.5
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
# 5  15.0          8         429.0        198    4341          10.0          70
# 6  14.0          8         454.0        220    4354           9.0          70
# 7  14.0          8         440.0        215    4312           8.5          70
# 8  14.0          8         455.0        225    4425          10.0          70
# 9  15.0          8         390.0        190    3850           8.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# ...

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.tail(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 388  26.0          4         156.0         92    2585          14.5
# 389  22.0          6         232.0        112    2835          14.7
# 390  32.0          4         144.0         96    2665          13.9
# 391  36.0          4         135.0         84    2370          13.0
# 392  27.0          4         151.0         90    2950          17.3
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                        name
# 388          82       1  chrysler lebaron medallion
# 389          82       1              ford granada l
# 390          82       3            toyota celica gt
# ...

# %%
set(df['cylinders'])
# Out:
# {3, 4, 5, 6, 8}

# %%
set(df['origin'])
# Out:
# {1, 2, 3}

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
list(df.columns)
# Out:
# ['mpg',
#  'cylinders',
#  'displacement',
#  'horsepower',
#  'weight',
#  'acceleration',
#  'model_year',
#  'origin',
#  'name']

# %%
df.values
# Out:
# array([[18.0, 8, 307.0, ..., 70, 1, 'chevrolet chevelle malibu'],
#        [15.0, 8, 350.0, ..., 70, 1, 'buick skylark 320'],
#        [18.0, 8, 318.0, ..., 70, 1, 'plymouth satellite'],
#        ...,
#        [32.0, 4, 135.0, ..., 82, 1, 'dodge rampage'],
#        [28.0, 4, 120.0, ..., 82, 1, 'ford ranger'],
#        [31.0, 4, 119.0, ..., 82, 1, 'chevy s-10']], dtype=object)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model_year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df['displacement'].max()
# Out:
# 455.0

# %%
df['displacement'].min()
# Out:
# 68.0

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.sort_values('displacement', ascending=False).head()
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 8   14.0          8         455.0        225    4425          10.0
# 95  12.0          8         455.0        225    4951          11.0
# 13  14.0          8         455.0        225    3086          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
#
#     model_year  origin                      name
# 8           70       1          pontiac catalina
# 95          73       1  buick electra 225 custom
# 13          70       1   buick estate wagon (sw)
# 6           70       1          chevrolet impala
# 7           70       1         plymouth fury iii

# %%
df.sort_values('displacement', ascending=False).tail()
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 131  32.0          4          71.0         65    1836          21.0
# 111  18.0          3          70.0         90    2124          13.5
# 71   19.0          3          70.0         97    2330          13.5
# 334  23.7          3          70.0        100    2420          12.5
# 117  29.0          4          68.0         49    1867          19.5
#
#      model_year  origin                 name
# 131          74       3  toyota corolla 1200
# 111          73       3            maxda rx3
# 71           72       3      mazda rx2 coupe
# 334          80       3        mazda rx-7 gs
# 117          73       2             fiat 128

# %%
df.horsepower.head()
# Out:
# 0    130
# 1    165
# 2    150
# 3    150
# 4    140
# Name: horsepower, dtype: object

# %%
df['horsepower'].head()
# Out:
# 0    130
# 1    165
# 2    150
# 3    150
# 4    140
# Name: horsepower, dtype: object

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df[2:4].head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
#
#    origin                name
# 2       1  plymouth satellite
# 3       1       amc rebel sst

# %%
df[['cylinders','name']].head()
# Out:
#    cylinders                       name
# 0          8  chevrolet chevelle malibu
# 1          8          buick skylark 320
# 2          8         plymouth satellite
# 3          8              amc rebel sst
# 4          8                ford torino

# %%
df.loc[1:10,['name']]
# Out:
#                    name
# 1     buick skylark 320
# 2    plymouth satellite
# 3         amc rebel sst
# 4           ford torino
# 5      ford galaxie 500
# 6      chevrolet impala
# 7     plymouth fury iii
# 8      pontiac catalina
# 9    amc ambassador dpl
# 10  dodge challenger se

# %%
df.loc[9,['name','origin']]
# Out:
# name      amc ambassador dpl
# origin                     1
# Name: 9, dtype: object

# %%
df.iloc[0:3,[0,3]]
# Out:
#     mpg horsepower
# 0  18.0        130
# 1  15.0        165
# 2  18.0        150

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model_year        int64
# origin            int64
# name             object
# dtype: object

# %%
df[df.weight == 3504]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu

# %%
df[df['cylinders'].isin([8])].head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df['displacement'].mean()
# Out:
# 193.42587939698493

# %%
df['displacement'].std()
# Out:
# 104.26983817119581

# %%
df['displacement'].max()
# Out:
# 455.0

# %%
df['displacement'].min()
# Out:
# 68.0

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.iloc[9:10,[2]]
# Out:
#    displacement
# 9         390.0

# %%
df.iloc[9,[1,2]]
# Out:
# cylinders         8
# displacement    390
# Name: 9, dtype: object

# %%
df.iloc[9,[1]] = 9

# %%
df.iloc[9,[1]]
# Out:
# cylinders    9
# Name: 9, dtype: object

# %%
len(df)
# Out:
# 398

# %%
df.loc[:,'cylinders'] = np.array([4]*len(df))

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          4         307.0        130    3504          12.0          70
# 1  15.0          4         350.0        165    3693          11.5          70
# 2  18.0          4         318.0        150    3436          11.0          70
# 3  16.0          4         304.0        150    3433          12.0          70
# 4  17.0          4         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          4         307.0        130    3504          12.0          70
# 1  15.0          4         350.0        165    3693          11.5          70
# 2  18.0          4         318.0        150    3436          11.0          70
# 3  16.0          4         304.0        150    3433          12.0          70
# 4  17.0          4         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.rename(columns = {'displacement':'dis'}, inplace=True)

# %%
df.head()
# Out:
#     mpg  cylinders    dis horsepower  weight  acceleration  model_year  \
# 0  18.0          4  307.0        130    3504          12.0          70
# 1  15.0          4  350.0        165    3693          11.5          70
# 2  18.0          4  318.0        150    3436          11.0          70
# 3  16.0          4  304.0        150    3433          12.0          70
# 4  17.0          4  302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
for index, row in df.iterrows():
    print(index, row["name"])
# Out:
# 0 chevrolet chevelle malibu
# 1 buick skylark 320
# 2 plymouth satellite
# 3 amc rebel sst
# 4 ford torino
# 5 ford galaxie 500
# 6 chevrolet impala
# 7 plymouth fury iii
# 8 pontiac catalina
# 9 amc ambassador dpl
# 10 dodge challenger se
# 11 plymouth 'cuda 340
# 12 chevrolet monte carlo
# 13 buick estate wagon (sw)
# 14 toyota corona mark ii
# 15 plymouth duster
# 16 amc hornet
# 17 ford maverick
# 18 datsun pl510
# 19 volkswagen 1131 deluxe sedan
# 20 peugeot 504
# 21 audi 100 ls
# 22 saab 99e
# 23 bmw 2002
# 24 amc gremlin
# 25 ford f250
# 26 chevy c20
# 27 dodge d200
# 28 hi 1200d
# 29 datsun pl510
# 30 chevrolet vega 2300
# 31 toyota corona
# 32 ford pinto
# 33 amc gremlin
# 34 plymouth satellite custom
# 35 chevrolet chevelle malibu
# 36 ford torino 500
# 37 amc matador
# 38 chevrolet impala
# 39 pontiac catalina brougham
# 40 ford galaxie 500
# 41 plymouth fury iii
# 42 dodge monaco (sw)
# 43 ford country squire (sw)
# 44 pontiac safari (sw)
# 45 amc hornet sportabout (sw)
# ...

# %%
df.to_csv('mpg_modified.csv')
