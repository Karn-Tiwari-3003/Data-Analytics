# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').agg(['count', 'mean', 'min', 'max'])
# Out:
#               beer_servings                      spirit_servings              \
#                       count        mean min  max           count        mean
# continent
# Africa                   53   61.471698   0  376              53   16.339623
# Asia                     44   37.045455   0  247              44   60.840909
# Europe                   45  193.777778   0  361              45  132.555556
# North America            23  145.434783   1  285              23  165.739130
# Oceania                  16   89.687500   0  306              16   58.437500
# South America            12  175.083333  93  333              12  114.750000
#
#                        wine_servings                       \
#               min  max         count        mean min  max
# continent
# Africa          0  152            53   16.264151   0  233
# Asia            0  326            44    9.068182   0  123
# Europe          0  373            45  142.222222   0  370
# ...

# %%
drinks.groupby('continent').beer_servings.agg(['count', 'mean', 'min', 'max'])
# Out:
#                count        mean  min  max
# continent
# Africa            53   61.471698    0  376
# Asia              44   37.045455    0  247
# Europe            45  193.777778    0  361
# North America     23  145.434783    1  285
# Oceania           16   89.687500    0  306
# South America     12  175.083333   93  333

# %%
# %matplotlib inline

# %%
drinks.groupby('continent').mean().plot(kind = 'bar')

# %%
drinks.groupby('continent').sum().plot(kind = 'bar')

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.groupby('genre').describe()
# Out:
#           star_rating                                                    \
#                 count      mean       std  min    25%   50%    75%  max
# genre
# Action          136.0  7.884559  0.333084  7.4  7.600  7.80  8.100  9.0
# Adventure        75.0  7.933333  0.361802  7.4  7.650  7.90  8.100  8.9
# Animation        62.0  7.914516  0.292444  7.4  7.700  7.90  8.100  8.6
# Biography        77.0  7.862338  0.310364  7.4  7.600  7.80  8.100  8.9
# Comedy          156.0  7.822436  0.304922  7.4  7.600  7.80  8.000  8.6
# Crime           124.0  7.916935  0.392143  7.4  7.600  7.80  8.100  9.3
# Drama           278.0  7.902518  0.328041  7.4  7.600  7.90  8.100  8.9
# Family            2.0  7.850000  0.070711  7.8  7.825  7.85  7.875  7.9
# Fantasy           1.0  7.700000       NaN  7.7  7.700  7.70  7.700  7.7
# Film-Noir         3.0  8.033333  0.305505  7.7  7.900  8.10  8.200  8.3
# History           1.0  8.000000       NaN  8.0  8.000  8.00  8.000  8.0
# ...

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
movies.genre.value_counts(normalize=True)
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Thriller     0.005107
# Sci-Fi       0.005107
# Film-Noir    0.003064
# Family       0.002043
# Fantasy      0.001021
# History      0.001021
# Name: genre, dtype: float64

# %%
type(movies.genre.value_counts(normalize=True))
# Out:
# pandas.core.series.Series

# %%
movies.genre.value_counts(normalize=True).head()
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Name: genre, dtype: float64

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df = pd.crosstab(movies.genre, movies.content_rating)

# %%
df['sum'] = df.sum(axis = 1)

# %%
df
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
pd.crosstab(movies.genre, movies.content_rating)
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.duration.max()
# Out:
# 242

# %%
movies.duration.min()
# Out:
# 64

# %%
movies.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
# 120    18
# 105    18
# 126    18
# 98     18
# 130    18
# 100    17
# 121    17
# 116    17
# 124    16
# 122    16
# 118    16
# 115    16
# 96     16
# 104    16
# 110    16
# 107    16
# 109    16
# 119    15
# 114    15
# 99     15
# 108    15
# 94     14
# 117    14
# 106    14
# 93     14
#        ..
# 70      1
# 69      1
# 67      1
# 66      1
# 242     1
# 238     1
# 195     1
# 229     1
# 224     1
# 220     1
# 216     1
# 212     1
# 207     1
# 205     1
# 202     1
# 201     1
# 200     1
# 194     1
# 159     1
# 193     1
# 187     1
# 186     1
# 184     1
# 183     1
# 182     1
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# %matplotlib inline

# %%
movies.duration.plot(kind = 'hist')

# %%
movies.genre.value_counts().plot(kind = 'bar')

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Colors Reported'].unique()
# Out:
# array([nan, 'RED', 'GREEN', 'BLUE', 'ORANGE', 'YELLOW', 'ORANGE YELLOW',
#        'RED GREEN', 'RED BLUE', 'RED ORANGE', 'RED GREEN BLUE',
#        'RED YELLOW GREEN', 'RED YELLOW', 'GREEN BLUE',
#        'ORANGE GREEN BLUE', 'ORANGE GREEN', 'YELLOW GREEN',
#        'RED YELLOW BLUE', 'ORANGE BLUE', 'RED YELLOW GREEN BLUE',
#        'YELLOW GREEN BLUE', 'RED ORANGE YELLOW', 'RED ORANGE YELLOW BLUE',
#        'YELLOW BLUE', 'RED ORANGE GREEN', 'RED ORANGE BLUE',
#        'ORANGE YELLOW GREEN', 'ORANGE YELLOW BLUE'], dtype=object)

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how ='any').shape
# Out:
# (2486, 5)

# %%
ufo.dropna(how ='all').shape
# Out:
# (18241, 5)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(subset=['City','Shape Reported'], how = 'all').shape
# Out:
# (18237, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'], how = 'any').shape
# Out:
# (15576, 5)

# %%
ufo['Shape Reported'].value_counts().plot(kind = 'bar')

# %%
ufo['Shape Reported'].value_counts(dropna = False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# HEXAGON         1
# FLARE           1
# PYRAMID         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].fillna(value='VARIOUS',inplace = True)

# %%
ufo['Shape Reported'].value_counts(dropna = False)
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# FLARE           1
# HEXAGON         1
# DOME            1
# PYRAMID         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].value_counts(dropna = False).plot(kind = 'bar')

# %%
import pandas as pd

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df = drinks.groupby('continent')['beer_servings'].describe()

# %%
df.head()
# Out:
#                count        mean        std  min     25%    50%     75%    max
# continent
# Africa          53.0   61.471698  80.557816  0.0   15.00   32.0   76.00  376.0
# Asia            44.0   37.045455  49.469725  0.0    4.25   17.5   60.50  247.0
# Europe          45.0  193.777778  99.631569  0.0  127.00  219.0  270.00  361.0
# North America   23.0  145.434783  79.621163  1.0   80.00  143.0  198.00  285.0
# Oceania         16.0   89.687500  96.641412  0.0   21.00   52.5  125.75  306.0

# %%
df.reset_index()
# Out:
#        continent  count        mean        std   min     25%    50%     75%  \
# 0         Africa   53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# 1           Asia   44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# 2         Europe   45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# 3  North America   23.0  145.434783  79.621163   1.0   80.00  143.0  198.00
# 4        Oceania   16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# 5  South America   12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#      max
# 0  376.0
# 1  247.0
# 2  361.0
# 3  285.0
# 4  306.0
# 5  333.0

# %%
df.plot(kind='bar')

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
len(drinks.columns)
# Out:
# 6

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks.ndim
# Out:
# 2

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
len(drinks.index)
# Out:
# 193

# %%
drinks[drinks.continent == 'South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %%
drinks.loc[0:6, ['continent','beer_servings']]
# Out:
#        continent  beer_servings
# 0           Asia              0
# 1         Europe             89
# 2         Africa             25
# 3         Europe            245
# 4         Africa            217
# 5  North America            102
# 6  South America            193

# %%
drinks.set_index('country', inplace=True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.loc['Brazil']
# Out:
# beer_servings                             245
# spirit_servings                           145
# wine_servings                              16
# total_litres_of_pure_alcohol              7.2
# continent                       South America
# Name: Brazil, dtype: object

# %%
drinks.index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua & Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'Tanzania', 'USA', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela',
#        'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='country', length=193)

# %%
drinks.columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.shape
# Out:
# (193, 5)

# %%
drinks.loc['India']
# Out:
# beer_servings                      9
# spirit_servings                  114
# wine_servings                      0
# total_litres_of_pure_alcohol     2.2
# continent                       Asia
# Name: India, dtype: object

# %%
drinks.index.name = None
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index.name = 'Country'
drinks.reset_index().head()
# Out:
#        Country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe(include = 'all')
# Out:
#         beer_servings  spirit_servings  wine_servings  \
# count      193.000000       193.000000     193.000000
# unique            NaN              NaN            NaN
# top               NaN              NaN            NaN
# freq              NaN              NaN            NaN
# mean       106.160622        80.994819      49.450777
# std        101.143103        88.284312      79.697598
# min          0.000000         0.000000       0.000000
# 25%         20.000000         4.000000       1.000000
# 50%         76.000000        56.000000       8.000000
# 75%        188.000000       128.000000      59.000000
# max        376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# top                              NaN    Africa
# freq                             NaN        53
# mean                        4.717098       NaN
# ...

# %%
drinks.describe(include = 'all').index
# Out:
# Index(['count', 'unique', 'top', 'freq', 'mean', 'std', 'min', '25%', '50%',
#        '75%', 'max'],
#       dtype='object')

# %%
drinks.describe(include = 'all').columns
# Out:
# Index(['beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks.describe(include = 'all').loc['25%', ['beer_servings','wine_servings']]
# Out:
# beer_servings    20
# wine_servings     1
# Name: 25%, dtype: object

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.reset_index(inplace=True)

# %%
drinks.index
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
drinks.head()
# Out:
#        Country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.set_index('Country', inplace=True)
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# Country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.continent.head()
# Out:
# Country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().values
# Out:
# array([53, 45, 44, 23, 16, 12], dtype=int64)

# %%
drinks.continent.value_counts()['Africa']
# Out:
# 53

# %%
drinks.continent.value_counts().sort_values()
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
people = pd.Series([3000000,500000], index = ['Albania', 'Andorra'], name='population')

# %%
people
# Out:
# Albania    3000000
# Andorra     500000
# Name: population, dtype: int64

# %%
drinks.beer_servings * people
# Out:
# Afghanistan                     NaN
# Albania                 267000000.0
# Algeria                         NaN
# Andorra                 122500000.0
# Angola                          NaN
# Antigua & Barbuda               NaN
# Argentina                       NaN
# Armenia                         NaN
# Australia                       NaN
# Austria                         NaN
# Azerbaijan                      NaN
# Bahamas                         NaN
# Bahrain                         NaN
# Bangladesh                      NaN
# Barbados                        NaN
# Belarus                         NaN
# Belgium                         NaN
# Belize                          NaN
# Benin                           NaN
# Bhutan                          NaN
# Bolivia                         NaN
# Bosnia-Herzegovina              NaN
# Botswana                        NaN
# Brazil                          NaN
# Brunei                          NaN
# Bulgaria                        NaN
# ...

# %%
pd.concat([drinks, people], axis = 1).head()
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent  population
# Afghanistan                           0.0      Asia         NaN
# Albania                               4.9    Europe   3000000.0
# ...

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.loc[1:10, ['City']]
# Out:
#                     City
# 1            Willingboro
# 2                Holyoke
# 3                Abilene
# 4   New York Worlds Fair
# 5            Valley City
# 6            Crater Lake
# 7                   Alma
# 8                Eklutna
# 9                Hubbard
# 10               Fontana

# %%
ufo.loc[[0,1,2], :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[:,'City':'State'].head()
# Out:
#                    City Colors Reported Shape Reported State
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY

# %%
ufo[['City','State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# ...

# %%
ufo.head(3).drop('Time', axis = 1)
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
ufo[ufo.City == 'Oakland']
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# ...

# %%
ufo.loc[ufo.City == 'Oakland' , :]
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# ...

# %%
ufo.iloc[:,[0,3]]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# ...

# %%
ufo.iloc[0:3, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col = 'country')

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.ix['Albania', 0]
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 89

# %%
drinks.ix[1, 'beer_servings']
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 89

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.ix['Albania' : 'Angola', 0:4]
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania             89              132             54
# Algeria             25                0             14
# Andorra            245              138            312
# Angola             217               57             45
#
#          total_litres_of_pure_alcohol
# country
# Albania                           4.9
# Algeria                           0.7
# Andorra                          12.4
# Angola                            5.9

# %%
drinks.ix[0:2,0:2]
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#              beer_servings  spirit_servings
# country
# Afghanistan              0                0
# Albania                 89              132

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('City', axis = 1, inplace = True)

# %%
ufo.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(how='any')
# Out:
#       Colors Reported Shape Reported State              Time
# 12                RED         SPHERE    SC   6/30/1939 20:00
# 19                RED          OTHER    AK   4/30/1943 23:00
# 36                RED      FORMATION    VA    7/10/1945 1:30
# 44              GREEN         SPHERE    CA   6/30/1946 19:00
# 82               BLUE        CHEVRON    CA   7/15/1947 21:00
# 84               BLUE           DISK    CA    8/8/1947 22:00
# 91                RED         SPHERE    IN   5/10/1948 19:00
# 111            ORANGE         CIRCLE    AL   8/15/1949 22:00
# 129             GREEN           DISK    CA    6/10/1950 0:00
# 138            ORANGE          CIGAR    ID    7/2/1950 13:00
# 152              BLUE           DISK    KS    4/15/1951 0:30
# 157             GREEN           DISK    MS   6/15/1951 20:30
# 163             GREEN         SPHERE    WY    7/3/1951 12:00
# 164              BLUE           DISK    UT   7/10/1951 23:30
# ...

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.shape
# Out:
# (193, 6)

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.1+ KB

# %%
drinks.describe(include='all')
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# count      193     193.000000       193.000000     193.000000
# unique     193            NaN              NaN            NaN
# top     Zambia            NaN              NaN            NaN
# freq         1            NaN              NaN            NaN
# mean       NaN     106.160622        80.994819      49.450777
# std        NaN     101.143103        88.284312      79.697598
# min        NaN       0.000000         0.000000       0.000000
# 25%        NaN      20.000000         4.000000       1.000000
# 50%        NaN      76.000000        56.000000       8.000000
# 75%        NaN     188.000000       128.000000      59.000000
# max        NaN     376.000000       438.000000     370.000000
#
#         total_litres_of_pure_alcohol continent
# count                     193.000000       193
# unique                           NaN         6
# top                              NaN    Africa
# ...

# %%
drinks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 30.4 KB

# %%
drinks.memory_usage()
# Out:
# Index                             80
# country                         1544
# beer_servings                   1544
# spirit_servings                 1544
# wine_servings                   1544
# total_litres_of_pure_alcohol    1544
# continent                       1544
# dtype: int64

# %%
drinks.memory_usage(deep=True)
# Out:
# Index                              80
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                       12332
# dtype: int64

# %%
drinks.memory_usage(deep=True).sum()
# Out:
# 31176

# %%
sorted(drinks.continent.unique())
# Out:
# ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']

# %%
drinks['continent'] = drinks.continent.astype('category')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
drinks.continent.cat.codes.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    0
# dtype: int8

# %%
drinks.memory_usage(deep=True)
# Out:
# Index                              80
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                         744
# dtype: int64

# %%
drinks.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null category
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 19.1 KB

# %%
drinks.country
# Out:
# 0               Afghanistan
# 1                   Albania
# 2                   Algeria
# 3                   Andorra
# 4                    Angola
# 5         Antigua & Barbuda
# 6                 Argentina
# 7                   Armenia
# 8                 Australia
# 9                   Austria
# 10               Azerbaijan
# 11                  Bahamas
# 12                  Bahrain
# 13               Bangladesh
# 14                 Barbados
# 15                  Belarus
# 16                  Belgium
# 17                   Belize
# 18                    Benin
# 19                   Bhutan
# 20                  Bolivia
# 21       Bosnia-Herzegovina
# 22                 Botswana
# 23                   Brazil
# 24                   Brunei
# 25                 Bulgaria
# 26             Burkina Faso
# 27                  Burundi
# 28            Cote d'Ivoire
# 29               Cabo Verde
#                ...
# 163                Suriname
# 164               Swaziland
# ...

# %%
df = pd.DataFrame({'ID':[1,2,3,4,5], 'quality' : ['good','bad', 'poor', 'very good', 'excellent']})

# %%
df
# Out:
#    ID    quality
# 0   1       good
# 1   2        bad
# 2   3       poor
# 3   4  very good
# 4   5  excellent

# %%
df.sort_values('quality')
# Out:
#    ID    quality
# 1   2        bad
# 4   5  excellent
# 0   1       good
# 2   3       poor
# 3   4  very good

# %%
df['quality'] = df.quality.astype('category', categories = ['good','bad','poor','very good', 'excellent'], ordered = True)
# Out:
# C:\Users\91961\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3296: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    ID    quality
# 0   1       good
# 1   2        bad
# 2   3       poor
# 3   4  very good
# 4   5  excellent

# %%
df.quality
# Out:
# 0         good
# 1          bad
# 2         poor
# 3    very good
# 4    excellent
# Name: quality, dtype: category
# Categories (5, object): [good < bad < poor < very good < excellent]

# %%
df.sort_values('quality')
# Out:
#    ID    quality
# 0   1       good
# 1   2        bad
# 2   3       poor
# 3   4  very good
# 4   5  excellent

# %%
df.loc[df.quality > 'poor', :]
# Out:
#    ID    quality
# 3   4  very good
# 4   5  excellent
